# %%
import pandas as pd
import matplotlib.pyplot as pyplot

def plot(x, y, title, xLabel, yLabel):
    fig, axis = pyplot.subplots()
   # axis.set_title(title)
    axis.set_ylabel(yLabel)
    axis.set_xlabel(xLabel)
    axis.scatter(x, y)
    axis.margins(x=0, y=0)
    

df = pd.read_csv("haddadPosts.tsv", "\t")
df.columns = ["id", "message", "date", "shares", "angry_reaction"]
df["date"] = pd.to_datetime(df["date"])
df.head()
xAxis = df["date"]
yAxis = df["shares"]
pyplot.rcParams["figure.figsize"] = [20, 10]
plot(xAxis, yAxis, "Popularidade postagens", "Date", "Shares")

# %%
def createHistogram(values, title, xLabel, yLabel):
    axes = values.plot(kind="bar")
    axes.set_title(title, fontsize=30)
    axes.set_xlabel(xLabel, fontsize=22)
    axes.set_ylabel(yLabel, fontsize=22)
    pyplot.show()
    
groupByMonth = df.groupby([df["date"].dt.year, df["date"].dt.month])["shares"].mean()
createHistogram(groupByMonth, "Numero de compartilhamentos mensais", "Compartilhamentos", "Data")

# %%
sortShared = df.sort_values("shares", ascending=False)
sortShared[["id", "shares"]].head(20)
# Out:
#                                     id  shares
# 633   904277726319518_2110110905736188   73245
# 765    904277726319518_770642973267313   63574
# 1150   904277726319518_237586120237229   54395
# 815   904277726319518_1975348815879065   51202
# 812   904277726319518_1382129525223236   50880
# 1685  904277726319518_1123544887726133   48526
# 1393  904277726319518_1236765659737388   46735
# 934   904277726319518_2054916448156124   44352
# 669   904277726319518_2008373709243242   44221
# 859    904277726319518_340215979884292   41994
# 1048   904277726319518_900112233516511   40599
# 769    904277726319518_255428838508479   40296
# 766    904277726319518_340637680021322   37023
# 828    904277726319518_348941819176246   36909
# 1432  904277726319518_1178370055576949   35910
# 1013  904277726319518_2218468014891257   35450
# 872    904277726319518_295630654601316   34765
# 1041   904277726319518_292829281532674   34464
# 779    904277726319518_274769466486039   34272
# 481   904277726319518_2197677893646155   33542

# %%
sortedAngry = df.sort_values("angry_reaction", ascending=False)
sortedAngry.head(20)
# Out:
#                                    id  \
# 574  904277726319518_2141636845916927
# 422  904277726319518_2241338135946797
# 595  904277726319518_2130298060384139
# 431  904277726319518_2225503914196886
# 798   904277726319518_541196666321680
# 615  904277726319518_2118908728189739
# 545  904277726319518_2158029657610979
# 439  904277726319518_2222452741168670
# 387  904277726319518_2262185507195393
# 655  904277726319518_2128565730805086
# 285  904277726319518_2333797386700871
# 445  904277726319518_2215553495191928
# 497  904277726319518_2188215354592409
